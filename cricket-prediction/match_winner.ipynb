# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('matches.csv')

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.drop(['id', 'dl_applied', 'win_by_runs', 'win_by_wickets' ,'player_of_match', 'umpire1', 'umpire2', 'umpire3', 'date', 'city'], axis=1, inplace=True)

# %%
df.drop(['season'],axis=1,inplace=True)

# %%
df.drop(['result'],axis=1,inplace=True)

# %%
df
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                      toss_winner toss_decision                       winner  \
# 0    Royal Challengers Bangalore         field          Sunrisers Hyderabad
# ...

# %%
df.isnull().sum()
# Out:
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           4
# venue            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams=['Sunrisers Hyderabad', 'Mumbai Indians', 'Royal Challengers Bangalore',
       'Kolkata Knight Riders', 'Kings XI Punjab','Chennai Super Kings', 
       'Rajasthan Royals', 'Delhi Capitals']
df=df[(df['team1'].isin(teams))&(df['team2'].isin(teams))]

# %%
df.replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)
# Out:
# /home/hrishikesh/.local/lib/python3.8/site-packages/pandas/core/frame.py:4373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
teams=list(enumerate(df['team1'].unique(), start=1))
map_list={value:key for key, value in teams}

# %%
map_list
# Out:
# {'Sunrisers Hyderabad': 1,
#  'Kolkata Knight Riders': 2,
#  'Royal Challengers Bangalore': 3,
#  'Kings XI Punjab': 4,
#  'Mumbai Indians': 5,
#  'Chennai Super Kings': 6,
#  'Rajasthan Royals': 7,
#  'Delhi Capitals': 8}

# %%
df[['team1', 'team2', 'toss_winner', 'winner']]=df[['team1', 'team2', 'toss_winner', 'winner']].apply(lambda x:x.map(map_list), axis=1)
# Out:
# /home/hrishikesh/.local/lib/python3.8/site-packages/pandas/core/frame.py:3062: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df=pd.get_dummies(df, columns=['toss_decision'], drop_first=True)

# %%
df['team1'] = df['team1'].astype('int64')
df['team2'] = df['team2'].astype('int64')
df['toss_winner'] = df['toss_winner'].astype('int64')
df['winner'] = df['winner'].astype('int64')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X=df.drop('winner', axis=1)
y=df['winner']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train, y_train)
log_reg.score(X_test, y_test)
# Out:
# /home/hrishikesh/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.367816091954023

# %%
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.5057471264367817

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt.score(X_test, y_test)
# Out:
# 0.47126436781609193

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('matches.csv')

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rt = RandomForestClassifier()

# %%
rt.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rt.score(X_test,y_test)
# Out:
# 0.4482758620689655

# %%
df = pd.read_csv('matches.csv')

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df.drop(['id','season','city','result','dl_applied','win_by_wickets','win_by_runs','player_of_match','umpire1','umpire2','umpire3'],axis=1,inplace=True)

# %%
df
# Out:
#            date                        team1                        team2  \
# 0    2017-04-05          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1    2017-04-06               Mumbai Indians       Rising Pune Supergiant
# 2    2017-04-07                Gujarat Lions        Kolkata Knight Riders
# 3    2017-04-08       Rising Pune Supergiant              Kings XI Punjab
# 4    2017-04-08  Royal Challengers Bangalore             Delhi Daredevils
# ..          ...                          ...                          ...
# 751    05/05/19        Kolkata Knight Riders               Mumbai Indians
# 752    07/05/19          Chennai Super Kings               Mumbai Indians
# 753    08/05/19          Sunrisers Hyderabad               Delhi Capitals
# 754    10/05/19               Delhi Capitals          Chennai Super Kings
# 755    12/05/19               Mumbai Indians          Chennai Super Kings
#
#                      toss_winner toss_decision                       winner  \
# ...

# %%
df.drop(['date','venue'],axis=1,inplace=True)

# %%
df
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                      toss_winner toss_decision                       winner
# 0    Royal Challengers Bangalore         field          Sunrisers Hyderabad
# ...

# %%
teams=['Sunrisers Hyderabad', 'Mumbai Indians', 'Royal Challengers Bangalore',
       'Kolkata Knight Riders', 'Kings XI Punjab','Chennai Super Kings', 
       'Rajasthan Royals', 'Delhi Capitals']
df=df[(df['team1'].isin(teams))&(df['team2'].isin(teams))]

# %%
df
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 6          Kolkata Knight Riders               Mumbai Indians
# 7    Royal Challengers Bangalore              Kings XI Punjab
# 9            Sunrisers Hyderabad               Mumbai Indians
# 10               Kings XI Punjab        Kolkata Knight Riders
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                     winner
# 0      Sunrisers Hyderabad
# 6           Mumbai Indians
# 7          Kings XI Punjab
# 9           Mumbai Indians
# 10   Kolkata Knight Riders
# ..                     ...
# ...

# %%
df.replace('Delhi Daredevils', 'Delhi Capitals', inplace=True)
# Out:
# /home/hrishikesh/.local/lib/python3.8/site-packages/pandas/core/frame.py:4373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
teams=list(enumerate(df['team1'].unique(), start=1))
map_list={value:key for key, value in teams}

# %%
df.isnull().sum()
# Out:
# team1            0
# team2            0
# toss_winner      0
# toss_decision    0
# winner           2
# dtype: int64

# %%
df.dropna()
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 6          Kolkata Knight Riders               Mumbai Indians
# 7    Royal Challengers Bangalore              Kings XI Punjab
# 9            Sunrisers Hyderabad               Mumbai Indians
# 10               Kings XI Punjab        Kolkata Knight Riders
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                      toss_winner toss_decision                 winner
# 0    Royal Challengers Bangalore         field    Sunrisers Hyderabad
# 6                 Mumbai Indians         field         Mumbai Indians
# ...

# %%
df[['team1', 'team2', 'toss_winner', 'winner']]=df[['team1', 'team2', 'toss_winner', 'winner']].apply(lambda x:x.map(map_list), axis=1)
# Out:
# /home/hrishikesh/.local/lib/python3.8/site-packages/pandas/core/frame.py:3062: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df
# Out:
#      team1  team2  toss_winner toss_decision  winner
# 0      1.0    3.0          3.0         field     1.0
# 6      2.0    5.0          5.0         field     5.0
# 7      3.0    4.0          3.0           bat     4.0
# 9      1.0    5.0          5.0         field     5.0
# 10     4.0    2.0          2.0         field     2.0
# ..     ...    ...          ...           ...     ...
# 751    2.0    5.0          5.0         field     5.0
# 752    6.0    5.0          6.0           bat     5.0
# 753    1.0    8.0          8.0         field     8.0
# 754    8.0    6.0          6.0         field     6.0
# 755    5.0    6.0          5.0           bat     5.0
#
# [437 rows x 5 columns]

# %%
df=pd.get_dummies(df, columns=['toss_decision'], drop_first=True)

# %%
df.isnull().sum()
# Out:
# team1                  0
# team2                  0
# toss_winner            0
# winner                 2
# toss_decision_field    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      team1  team2  toss_winner  winner  toss_decision_field
# 0      1.0    3.0          3.0     1.0                    1
# 6      2.0    5.0          5.0     5.0                    1
# 7      3.0    4.0          3.0     4.0                    0
# 9      1.0    5.0          5.0     5.0                    1
# 10     4.0    2.0          2.0     2.0                    1
# ..     ...    ...          ...     ...                  ...
# 751    2.0    5.0          5.0     5.0                    1
# 752    6.0    5.0          6.0     5.0                    0
# 753    1.0    8.0          8.0     8.0                    1
# 754    8.0    6.0          6.0     6.0                    1
# 755    5.0    6.0          5.0     5.0                    0
#
# [435 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# team1                  0
# team2                  0
# toss_winner            0
# winner                 0
# toss_decision_field    0
# dtype: int64

# %%
df['team1'] = df['team1'].astype('int64')
df['team2'] = df['team2'].astype('int64')
df['toss_winner'] = df['toss_winner'].astype('int64')
df['winner'] = df['winner'].astype('int64')

# %%
df
# Out:
#      team1  team2  toss_winner  winner  toss_decision_field
# 0        1      3            3       1                    1
# 6        2      5            5       5                    1
# 7        3      4            3       4                    0
# 9        1      5            5       5                    1
# 10       4      2            2       2                    1
# ..     ...    ...          ...     ...                  ...
# 751      2      5            5       5                    1
# 752      6      5            6       5                    0
# 753      1      8            8       8                    1
# 754      8      6            6       6                    1
# 755      5      6            5       5                    0
#
# [435 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X=df.drop('winner', axis=1)
y=df['winner']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)

# %%
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.4827586206896552

# %%
knn.predict(X_test)
# Out:
# array([4, 4, 5, 1, 3, 6, 4, 5, 1, 2, 6, 6, 2, 6, 5, 5, 5, 7, 6, 6, 5, 5,
#        2, 4, 5, 6, 6, 5, 2, 5, 6, 3, 2, 6, 6, 1, 4, 6, 7, 2, 6, 6, 2, 2,
#        3, 5, 1, 1, 5, 5, 6, 3, 7, 4, 2, 3, 5, 4, 5, 1, 7, 4, 3, 6, 6, 4,
#        6, 2, 5, 3, 8, 7, 7, 6, 2, 1, 2, 1, 7, 6, 6, 1, 6, 6, 4, 4, 4])

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier()

# %%
mlp.fit(X_train,y_train)
# Out:
# /home/hrishikesh/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
mlp.score(X_test,y_test)
# Out:
# 0.3448275862068966

# %%
df
# Out:
#      team1  team2  toss_winner  winner  toss_decision_field
# 0        1      3            3       1                    1
# 6        2      5            5       5                    1
# 7        3      4            3       4                    0
# 9        1      5            5       5                    1
# 10       4      2            2       2                    1
# ..     ...    ...          ...     ...                  ...
# 751      2      5            5       5                    1
# 752      6      5            6       5                    0
# 753      1      8            8       8                    1
# 754      8      6            6       6                    1
# 755      5      6            5       5                    0
#
# [435 rows x 5 columns]

# %%
df1 = df.drop(['toss_winner','winner','toss_decision_field'],axis=1)

# %%
df1
# Out:
#      team1  team2
# 0        1      3
# 6        2      5
# 7        3      4
# 9        1      5
# 10       4      2
# ..     ...    ...
# 751      2      5
# 752      6      5
# 753      1      8
# 754      8      6
# 755      5      6
#
# [435 rows x 2 columns]

# %%
df
# Out:
#      team1  team2  toss_winner  winner  toss_decision_field
# 0        1      3            3       1                    1
# 6        2      5            5       5                    1
# 7        3      4            3       4                    0
# 9        1      5            5       5                    1
# 10       4      2            2       2                    1
# ..     ...    ...          ...     ...                  ...
# 751      2      5            5       5                    1
# 752      6      5            6       5                    0
# 753      1      8            8       8                    1
# 754      8      6            6       6                    1
# 755      5      6            5       5                    0
#
# [435 rows x 5 columns]

# %%
df2 = df.drop(['toss_winner','toss_decision_field'],axis=1)

# %%
df2
# Out:
#      team1  team2  winner
# 0        1      3       1
# 6        2      5       5
# 7        3      4       4
# 9        1      5       5
# 10       4      2       2
# ..     ...    ...     ...
# 751      2      5       5
# 752      6      5       5
# 753      1      8       8
# 754      8      6       6
# 755      5      6       5
#
# [435 rows x 3 columns]

# %%
X=df2.drop('winner', axis=1)
y=df2['winner']
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2)

# %%
knn=KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.5057471264367817

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt.score(X_test, y_test)
# Out:
# 0.47126436781609193

# %%
import pandas as pd
df = pd.read_csv('matches.csv')

# %%
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df.drop(['id','season','toss_winner','toss_decision','result','dl_applied','player_of_match','umpire1','umpire2','umpire3'],axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.drop(['city','date','win_by_runs','win_by_wickets','venue'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# team1     0
# team2     0
# winner    0
# dtype: int64

# %%
final = pd.get_dummies(df, prefix=['team1', 'team2'], columns=['team1', 'team2'])

X = final.drop(['winner'], axis=1)
y = final["winner"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X
# Out:
#      team1_Chennai Super Kings  team1_Deccan Chargers  team1_Delhi Capitals  \
# 0                            0                      0                     0
# 1                            0                      0                     0
# 2                            0                      0                     0
# 3                            0                      0                     0
# 4                            0                      0                     0
# ..                         ...                    ...                   ...
# 751                          0                      0                     0
# 752                          1                      0                     0
# 753                          0                      0                     0
# 754                          0                      0                     1
# 755                          0                      0                     0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, max_features='sqrt', max_depth=20,random_state=0) 
rf.fit(X_train, y_train)
score = rf.score(X_train, y_train)
score2 = rf.score(X_test, y_test)
print("Training set accuracy: ", '%.3f'%(score))
print("Test set accuracy: ", '%.3f'%(score2))
# Out:
# Training set accuracy:  0.716
# Test set accuracy:  0.522

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_test,y_test)
# Out:
# 0.5089285714285714

# %%
final
# Out:
#                           winner  team1_Chennai Super Kings  \
# 0            Sunrisers Hyderabad                          0
# 1         Rising Pune Supergiant                          0
# 2          Kolkata Knight Riders                          0
# 3                Kings XI Punjab                          0
# 4    Royal Challengers Bangalore                          0
# ..                           ...                        ...
# 751               Mumbai Indians                          0
# 752               Mumbai Indians                          1
# 753               Delhi Capitals                          0
# 754          Chennai Super Kings                          0
# 755               Mumbai Indians                          0
#
#      team1_Deccan Chargers  team1_Delhi Capitals  team1_Delhi Daredevils  \
# 0                        0                     0                       0
# 1                        0                     0                       0
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
rfc = RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=100, oob_score = True) 

param_grid = { 
    'n_estimators': [1, 100],
    'max_features': ['auto', 'sqrt', 'log2']
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_)
# Out:
# /home/hrishikesh/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# /home/hrishikesh/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:540: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /home/hrishikesh/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:544: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
# /home/hrishikesh/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:540: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# ...

# %%
import tabula

# Read PDF into list of DataFrame
df = tabula.read_pdf("schedule.pdf")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
import tabula

# %%
df
# Out:
# [    Match No                                     Match Center  \
#  0        1.0       Mumbai Indians (MI) Vs Chennai Super Kings
#  1        NaN                                            (CSK)
#  2        2.0    Delhi Capitals (DC) Vs Kings XI Punjab (KXIP)
#  3        3.0     Royal Challengers Bangalore (RCB) Vs Kolkata
#  4        NaN                              Knight Riders (KKR)
#  5        4.0     Sun Risers Hyderabad (SRH) Vs Mumbai Indians
#  6        NaN                                             (MI)
#  7        5.0           Chennai Super Kings (CSK) Vs Rajasthan
#  8        NaN                                      Royals (RR)
#  9        6.0    Kolkata Knight Riders (KKR) Vs Delhi Capitals
#  10       NaN                                             (DC)
#  11       7.0   Kings XI Punjab (KXIP) Vs Sun Risers Hyderabad
#  12       NaN                                            (SRH)
#  13       8.0         Mumbai Indians (MI) Vs Royal Challengers
# ...

# %%
type(df)
# Out:
# list

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:@localhost/cricket_prediction', echo=False)

# %%
import pandas as pd
fixtures = pd.read_sql('ipl_schedule',engine)

# %%
fixtures
# Out:
#     id                              team1               date        day  \
# 0    1                Mumbai Indians (MI)  19 September 2020   Saturday
# 1    2                Delhi Capitals (DC)  20 September 2020     Sunday
# 2    3         Sun Risers Hyderabad (SRH)  21 September 2020     Monday
# 3    4              Rajasthan Royals (RR)  22 September 2020    Tuesday
# 4    5        Kolkata Knight Riders (KKR)  23 September 2020  Wednesday
# 5    6             Kings XI Punjab (KXIP)  24 September 2020   Thursday
# 6    7          Chennai Super Kings (CSK)  25 September 2020     Friday
# 7    8        Kolkata Knight Riders (KKR)  26 September 2020   Saturday
# 8    9              Rajasthan Royals (RR)  27 September 2020     Sunday
# 9   10  Royal Challengers Bangalore (RCB)  28 September 2020     Monday
# 10  11                Delhi Capitals (DC)  29 September 2020    Tuesday
# 11  12              Rajasthan Royals (RR)  30 September 2020  Wednesday
# ...

# %%
fixtures.drop(['city','time'],axis=1,inplace=True)

# %%
fixtures
# Out:
#     id                              team1               date        day  \
# 0    1                Mumbai Indians (MI)  19 September 2020   Saturday
# 1    2                Delhi Capitals (DC)  20 September 2020     Sunday
# 2    3         Sun Risers Hyderabad (SRH)  21 September 2020     Monday
# 3    4              Rajasthan Royals (RR)  22 September 2020    Tuesday
# 4    5        Kolkata Knight Riders (KKR)  23 September 2020  Wednesday
# 5    6             Kings XI Punjab (KXIP)  24 September 2020   Thursday
# 6    7          Chennai Super Kings (CSK)  25 September 2020     Friday
# 7    8        Kolkata Knight Riders (KKR)  26 September 2020   Saturday
# 8    9              Rajasthan Royals (RR)  27 September 2020     Sunday
# 9   10  Royal Challengers Bangalore (RCB)  28 September 2020     Monday
# 10  11                Delhi Capitals (DC)  29 September 2020    Tuesday
# 11  12              Rajasthan Royals (RR)  30 September 2020  Wednesday
# ...

# %%
fixtures.drop(['id','day'],axis=1,inplace=True)

# %%
pred_set = []

# %%
for index, row in fixtures.iterrows():
    pred_set.append({'team1': row['team1'], 'team2': row['team2'], 'winner': None})
        
pred_set = pd.DataFrame(pred_set)
backup_pred_set = pred_set
pred_set.head()
# Out:
#                          team1                              team2 winner
# 0          Mumbai Indians (MI)          Chennai Super Kings (CSK)   None
# 1          Delhi Capitals (DC)             Kings XI Punjab (KXIP)   None
# 2   Sun Risers Hyderabad (SRH)  Royal Challengers Bangalore (RCB)   None
# 3        Rajasthan Royals (RR)          Chennai Super Kings (CSK)   None
# 4  Kolkata Knight Riders (KKR)                Mumbai Indians (MI)   None

# %%
pred_set
# Out:
#                                 team1                              team2  \
# 0                 Mumbai Indians (MI)          Chennai Super Kings (CSK)
# 1                 Delhi Capitals (DC)             Kings XI Punjab (KXIP)
# 2          Sun Risers Hyderabad (SRH)  Royal Challengers Bangalore (RCB)
# 3               Rajasthan Royals (RR)          Chennai Super Kings (CSK)
# 4         Kolkata Knight Riders (KKR)                Mumbai Indians (MI)
# 5              Kings XI Punjab (KXIP)  Royal Challengers Bangalore (RCB)
# 6           Chennai Super Kings (CSK)                Delhi Capitals (DC)
# 7         Kolkata Knight Riders (KKR)         Sun Risers Hyderabad (SRH)
# 8               Rajasthan Royals (RR)             Kings XI Punjab (KXIP)
# 9   Royal Challengers Bangalore (RCB)                Mumbai Indians (MI)
# 10                Delhi Capitals (DC)         Sun Risers Hyderabad (SRH)
# 11              Rajasthan Royals (RR)        Kolkata Knight Riders (KKR)
# ...

# %%
pred_set = pd.get_dummies(pred_set, prefix=['team1', 'team2'], columns=['team1', 'team2'])

missing_cols = set(final.columns) - set(pred_set.columns)
for c in missing_cols:
    pred_set[c] = 0
pred_set = pred_set[final.columns]


pred_set = pred_set.drop(['winner'], axis=1)
pred_set.head()
# Out:
#    team1_Chennai Super Kings  team1_Deccan Chargers  team1_Delhi Capitals  \
# 0                          0                      0                     0
# 1                          0                      0                     0
# 2                          0                      0                     0
# 3                          0                      0                     0
# 4                          0                      0                     0
#
#    team1_Delhi Daredevils  team1_Gujarat Lions  team1_Kings XI Punjab  \
# 0                       0                    0                      0
# 1                       0                    0                      0
# 2                       0                    0                      0
# 3                       0                    0                      0
# 4                       0                    0                      0
#
#    team1_Kochi Tuskers Kerala  team1_Kolkata Knight Riders  \
# ...

# %%
predictions = rf.predict(pred_set)
for i in range(fixtures.shape[0]):
    print(backup_pred_set.iloc[i, 1] + " and " + backup_pred_set.iloc[i, 0])
    if predictions[i] == 1:
        print("Winner: " + backup_pred_set.iloc[i, 1])
    
    else:
        print("Winner: " + backup_pred_set.iloc[i, 0])
    print("")
# Out:
# Chennai Super Kings (CSK) and Mumbai Indians (MI)
# Winner: Mumbai Indians (MI)
#
# Kings XI Punjab (KXIP) and Delhi Capitals (DC)
# Winner: Delhi Capitals (DC)
#
# Royal Challengers Bangalore (RCB) and Sun Risers Hyderabad (SRH)
# Winner: Sun Risers Hyderabad (SRH)
#
# Chennai Super Kings (CSK) and Rajasthan Royals (RR)
# Winner: Rajasthan Royals (RR)
#
# Mumbai Indians (MI) and Kolkata Knight Riders (KKR)
# Winner: Kolkata Knight Riders (KKR)
#
# Royal Challengers Bangalore (RCB) and Kings XI Punjab (KXIP)
# Winner: Kings XI Punjab (KXIP)
#
# Delhi Capitals (DC) and Chennai Super Kings (CSK)
# Winner: Chennai Super Kings (CSK)
#
# Sun Risers Hyderabad (SRH) and Kolkata Knight Riders (KKR)
# Winner: Kolkata Knight Riders (KKR)
#
# Kings XI Punjab (KXIP) and Rajasthan Royals (RR)
# Winner: Rajasthan Royals (RR)
#
# Mumbai Indians (MI) and Royal Challengers Bangalore (RCB)
# Winner: Royal Challengers Bangalore (RCB)
#
# Sun Risers Hyderabad (SRH) and Delhi Capitals (DC)
# ...

# %%
rf.score(X_test,y_test)
# Out:
# 0.5223214285714286

# %%
backup_pred_set
# Out:
#                                 team1                              team2  \
# 0                 Mumbai Indians (MI)          Chennai Super Kings (CSK)
# 1                 Delhi Capitals (DC)             Kings XI Punjab (KXIP)
# 2          Sun Risers Hyderabad (SRH)  Royal Challengers Bangalore (RCB)
# 3               Rajasthan Royals (RR)          Chennai Super Kings (CSK)
# 4         Kolkata Knight Riders (KKR)                Mumbai Indians (MI)
# 5              Kings XI Punjab (KXIP)  Royal Challengers Bangalore (RCB)
# 6           Chennai Super Kings (CSK)                Delhi Capitals (DC)
# 7         Kolkata Knight Riders (KKR)         Sun Risers Hyderabad (SRH)
# 8               Rajasthan Royals (RR)             Kings XI Punjab (KXIP)
# 9   Royal Challengers Bangalore (RCB)                Mumbai Indians (MI)
# 10                Delhi Capitals (DC)         Sun Risers Hyderabad (SRH)
# 11              Rajasthan Royals (RR)        Kolkata Knight Riders (KKR)
# ...

# %%
pred_set
# Out:
#     team1_Chennai Super Kings  team1_Deccan Chargers  team1_Delhi Capitals  \
# 0                           0                      0                     0
# 1                           0                      0                     0
# 2                           0                      0                     0
# 3                           0                      0                     0
# 4                           0                      0                     0
# 5                           0                      0                     0
# 6                           0                      0                     0
# 7                           0                      0                     0
# 8                           0                      0                     0
# 9                           0                      0                     0
# 10                          0                      0                     0
# ...

# %%
a = {"a":[]}

# %%
a["a"].append(2)

# %%
a
# Out:
# {'a': [2]}

# %%
x = pd.DataFrame(a)

# %%
x
# Out:
#    a
# 0  2

# %%
table = {"team1":[],"team2":[],"winner":[]}
predictions = rf.predict(pred_set)
for i in range(fixtures.shape[0]):
    table["team1"].append(backup_pred_set.iloc[i,1])
    table["team2"].append(backup_pred_set.iloc[i,0])
    if predictions[i] == 1:
        table["winner"].append(backup_pred_set.iloc[i, 1])
    
    else:
        table["winner"].append(backup_pred_set.iloc[i, 0])
    print("")

# %%
table
# Out:
# {'team1': [' Chennai Super Kings (CSK)',
#   ' Kings XI Punjab (KXIP)',
#   ' Kolkata Knight Riders (KKR)',
#   ' Mumbai Indians (MI)',
#   ' Rajasthan Royals (RR)',
#   ' Delhi Capitals (DC)',
#   ' Sun Risers Hyderabad (SRH)',
#   ' Royal Challengers Bangalore (RCB)',
#   ' Delhi Capitals (DC)',
#   ' Chennai Super Kings (CSK)',
#   ' Sun Risers Hyderabad (SRH)',
#   ' Mumbai Indians (MI)',
#   ' Kolkata Knight Riders (KKR)',
#   ' Royal Challengers Bangalore (RCB)',
#   ' Kings XI Punjab (KXIP)',
#   ' Rajasthan Royals (RR)',
#   ' Mumbai Indians (MI)',
#   ' Chennai Super Kings (CSK)',
#   ' Royal Challengers Bangalore (RCB)',
#   ' Rajasthan Royals (RR)',
#   ' Kolkata Knight Riders (KKR)',
#   ' Chennai Super Kings (CSK)',
#   ' Rajasthan Royals (RR)',
#   ' Kolkata Knight Riders (KKR)',
#   ' Sun Risers Hyderabad (SRH)',
#   ' Kings XI Punjab (KXIP)',
#   ' Sun Risers Hyderabad (SRH)',
#   ' Delhi Capitals (DC)',
#   ' Kings XI Punjab (KXIP)',
#   ' Mumbai Indians (MI)',
# ...

# %%
tabel_df = pd.DataFrame(table)

# %%
tabel_df
# Out:
#                                  team1                                team2  \
# 0            Chennai Super Kings (CSK)                 Mumbai Indians (MI)
# 1               Kings XI Punjab (KXIP)                 Delhi Capitals (DC)
# 2          Kolkata Knight Riders (KKR)   Royal Challengers Bangalore (RCB)
# 3                  Mumbai Indians (MI)          Sun Risers Hyderabad (SRH)
# 4                Rajasthan Royals (RR)           Chennai Super Kings (CSK)
# 5                  Delhi Capitals (DC)         Kolkata Knight Riders (KKR)
# 6           Sun Risers Hyderabad (SRH)              Kings XI Punjab (KXIP)
# 7    Royal Challengers Bangalore (RCB)                 Mumbai Indians (MI)
# 8                  Delhi Capitals (DC)               Rajasthan Royals (RR)
# 9            Chennai Super Kings (CSK)         Kolkata Knight Riders (KKR)
# 10          Sun Risers Hyderabad (SRH)   Royal Challengers Bangalore (RCB)
# ...

# %%
import pickle 

pickle.dump(rf, open('matches.pkl','wb'))

# %%
new_set = {'team1':['Kolkata Knight Riders(KKR)'],'team2':['Chennai Super Kings']}

# %%
new_set = pd.DataFrame(new_set)

# %%
new_set
# Out:
#                         team1                team2
# 0  Kolkata Knight Riders(KKR)  Chennai Super Kings

# %%
predictions = rf.predict(pred_set)
for i in range(new_set.shape[0]):
    print(new_set.iloc[i, 1] + " and " + new_set.iloc[i, 0])
    if predictions[i] == 1:
        print("Winner: " + new_set.iloc[i, 1])
    
    else:
        print("Winner: " + new_set.iloc[i, 0])
    print("")
# Out:
# Chennai Super Kings and Kolkata Knight Riders(KKR)
# Winner: Kolkata Knight Riders(KKR)

# %%
new_set = {'team1':['Mumbai Indians(MI)'],'team2':['Kings XI Punjab(KXIP)']}

# %%
predictions = rf.predict(pred_set)
for i in range(new_set.shape[0]):
    print(new_set.iloc[i, 1] + " and " + new_set.iloc[i, 0])
    if predictions[i] == 1:
        print("Winner: " + new_set.iloc[i, 1])
    
    else:
        print("Winner: " + new_set.iloc[i, 0])
    print("")
# Out:
# Kings XI Punjab(KXIP) and Mumbai Indians(MI)
# Winner: Mumbai Indians(MI)

# %%
new_set = {'team1':['Mumbai Indians(MI)'],'team2':['Kolkata Knight Riders(KKR)']}

# %%
predictions = rf.predict(pred_set)
for i in range(new_set.shape[0]):
    print(new_set.iloc[i, 1] + " and " + new_set.iloc[i, 0])
    if predictions[i] == 1:
        print("Winner: " + new_set.iloc[i, 1])
    
    else:
        print("Winner: " + new_set.iloc[i, 0])
    print("")
# Out:
# Kolkata Knight Riders(KKR) and Mumbai Indians(MI)
# Winner: Mumbai Indians(MI)
